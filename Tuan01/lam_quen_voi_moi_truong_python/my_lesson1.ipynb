# %% [markdown]
# # “Thuc hanh tri tue nhan tao Buoi 1”
# ## “Noi dung thuc hanh”

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print("Hello, Python World!")

# %% [markdown]
# ### Tinh toan don gian

# %%
# %run ex1_calc.py

# %% [markdown]
# ### Tinh chu vi va dien tich hinh tron

# %%
# %run ex3_circle.py

# %% [markdown]
# # Ket Thuc
